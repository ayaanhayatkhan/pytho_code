# %% [markdown]
# # Expressions
#
# Let's start with some basic expressions

# %%
17

# %%
-2 + 15

# %%
-2 - 1

# %%
-2 -     -1

# %%
14 / 3
# Out:
# 4.666666666666667

# %%
1 / 2
# Out:
# 0.5

# %%
1 % 2
# Out:
# 1

# %%
15 % 2
# Out:
# 1

# %%
1 / 2.0
# Out:
# 0.5

# %%
type(1)
# Out:
# int

# %%
type(1/2)   # Different in Python 2
# Out:
# float

# %%
1/4.0 + 1/2
# Out:
# 0.75

# %%
2.1 + 5.3
# Out:
# 7.4

# %%
2 + 2 * 2
# Out:
# 6

# %%
(2 + 2) * 2 # overriding precedence
# Out:
# 8

# %% [markdown]
# See more about precedence here: https://docs.python.org/3/reference/expressions.html#operator-precedence

# %%
3 < 4        # conditional expression
# Out:
# True

# %%
3 == 4
# Out:
# False

# %%
3 == 3
# Out:
# True

# %%
a = 3 # ignore the *details* of the error for now
a = 'hello' 
b = "world"
print(a,b)
# Out:
# hello world

# %%
3 > 4
# Out:
# False

# %%
3 >= 3
# Out:
# True

# %%
2 <= 1
# Out:
# False

# %% [markdown]
# ## Other types of expressions

# %%
'abc'
# Out:
# 'abc'

# %%
"xyz"
# Out:
# 'xyz'

# %%
"""This is called a multi-line string.     
It can, obviously, span multiple lines! """
# Out:
# 'This is called a multi-line string.     \nIt can, obviously, span multiple lines! '

# %%
"ab" + "cd"
# Out:
# 'abcd'

# %%
type("ab")
# Out:
# str

# %%
"a-" * 3
# Out:
# 'a-a-a-'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True or False and False or False
# Out:
# True

# %%
(True or False) and (False or False)
# Out:
# False

# %% [markdown]
# # Call Expressions

# %%
max(7, 9)
# Out:
# 9

# %%
max(2+25, 9)
# Out:
# 27

# %%
pow(3, 2)
# Out:
# 9

# %%
max( min(1, -2) , min( pow(3, 5) , -4)    )
# Out:
# -2
